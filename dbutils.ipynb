# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.mkdirs("/Volumes/sample_catalog/default/db_catalog/New_Dir_by_utils")

# %%
dbutils.fs.ls("/Volumes/sample_catalog/default/db_catalog")

# %%
dbutils.fs.cp("/Volumes/sample_catalog/default/db_catalog/customer.csv", "/Volumes/sample_catalog/default/db_catalog/New_Dir_by_utils/", False)

# %%
dbutils.fs.rm("/Volumes/sample_catalog/default/db_catalog/New_Dir_by_utils/customer.csv", False)

# %%
# %fs
ls /Volumes/sample_catalog/default/db_catalog/

# %%
# %fs
mkdirs /Volumes/sample_catalog/default/db_catalog/New_Dir_by_using_magic_command/
